# %% [markdown]
# # Continuous Control
#
# ---
#
#
# ### Start the Environment
#
# Run the next code cell to install a few packages. This might take a few minutes to run.

# %%
import numpy as np
import gym
import random
import torch
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

from ddpg_agent import Agent

# %%
import numpy as np


# select this option to load version 1 (with a single agent) of the environment
# env = UnityEnvironment(file_name='/data/Reacher_One_Linux_NoVis/Reacher_One_Linux_NoVis.x86_64')

# select this option to load version 2 (with 20 agents) of the environment
env = gym.make("BipedalWalker-v3", render_mode='human')

state_size = env.observation_space.shape[0]
action_size = env.action_space.shape[0]
num_agents = 1

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)

# size of each action
action_size = brain.vector_action_space_size

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/oreadeniyi/Desktop/DDPG Reinforcement Learning/train_agent.ipynb Cell 5 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/oreadeniyi/Desktop/DDPG%20Reinforcement%20Learning/train_agent.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # reset the environment
# ----> <a href='vscode-notebook-cell:/Users/oreadeniyi/Desktop/DDPG%20Reinforcement%20Learning/train_agent.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> env_info = env.reset(train_mode=True)[brain_name]
#       <a href='vscode-notebook-cell:/Users/oreadeniyi/Desktop/DDPG%20Reinforcement%20Learning/train_agent.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> # number of agents
#       <a href='vscode-notebook-cell:/Users/oreadeniyi/Desktop/DDPG%20Reinforcement%20Learning/train_agent.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> num_agents = len(env_info.agents)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/gym/wrappers/time_limit.py:68, in TimeLimit.reset(self, **kwargs)
#      59 """Resets the environment with :param:`**kwargs` and sets the number of steps elapsed to zero.
#      60
#      61 Args:
#    (...)
#      65     The reset environment
#      66 """
#      67 self._elapsed_steps = 0
# ---> 68 return self.env.reset(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py:42, in OrderEnforcing.reset(self, **kwargs)
#      40 """Resets the environment with `kwargs`."""
#      41 self._has_reset = True
# ---> 42 return self.env.reset(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/gym/wrappers/env_checker.py:45, in PassiveEnvChecker.reset(self, **kwargs)
#      43 if self.checked_reset is False:
#      44     self.checked_reset = True
# ---> 45     return env_reset_passive_checker(self.env, **kwargs)
#      46 else:
#      47     return self.env.reset(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:192, in env_reset_passive_checker(env, **kwargs)
#     187     logger.warn(
#     188         "Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information."
#     189     )
#     191 # Checks the result of env.reset with kwargs
# --> 192 result = env.reset(**kwargs)
#     194 if not isinstance(result, tuple):
#     195     logger.warn(
#     196         f"The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `{type(result)}`"
#     197     )
#
# TypeError: reset() got an unexpected keyword argument 'train_mode'

# %% [markdown]
# ### Train a DDPG agent
#
# Run the code cells below to train the agent.

# %%
agent = Agent(state_size=state_size, action_size=action_size, num_agents=num_agents, random_seed=np.random.randint(100))

# %%
def ddpg(n_episodes=5000, max_t=10000, print_every=30):
    scores_deque = deque(maxlen=print_every)
    scores = []
    for i_episode in range(1, n_episodes+1):
        state = env.reset()
        score = np.zeros(num_agents)
        for t in range(max_t):
            actual_state = state[0] if isinstance(state, tuple) else state
            state = actual_state
            action = agent.act(actual_state)
   
            next_state, reward, done, info,_ = env.step(action)
             

            
            agent.step(state, action, reward, next_state, done)
            state = next_state
            score += reward
            if done:
                break 
        scores_deque.append(np.mean(score))
        scores.append(np.mean(score))
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores